# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/STEFA/Desktop/github/Dados_Servidores_CE_Streamlit/datasets/format.csv",index_col=False)
df
# Out:
#          Index                             Servidor       Orgao  \
# 0            0       ANTONIO MARCONI LEMOS DA SILVA         CGE
# 1            1                DENISE ANDRADE ARAUJO         CGE
# 2            2         ANTONIO SERGIO BELTRAO MAFRA         CGE
# 3            3             EMERSON CARVALHO DE LIMA         CGE
# 4            4                  GEORGE DANTAS NUNES         CGE
# ...        ...                                  ...         ...
# 159448  159832                   ANA PAULA DE MOURA  SEDUC-CPTD
# 159449  159833                  JOSE THOME DA FROTA       SEDET
# 159450  159834        MARIA APARECIDA MOURA DE LIMA  SEDUC-CPTD
# 159451  159835                  TIAGO REZENDE LEITE       SEDET
# 159452  159836  LUIZA CRISTINA DE ALENCAR RODRIGUES       SEDET
#
#                               Cargo SituacaoFuncional  TotalDescontos  \
# 0       AUDITOR DE CONTROLE INTERNO             Ativo        15028.27
# 1       AUDITOR DE CONTROLE INTERNO             Ativo        14714.46
# 2       AUDITOR DE CONTROLE INTERNO             Ativo         9215.62
# 3       AUDITOR DE CONTROLE INTERNO             Ativo        12159.20
# 4       AUDITOR DE CONTROLE INTERNO             Ativo         8545.36
# ...                             ...               ...             ...
# 159448              PROF CTPD PEDAG             Ativo          642.01
# 159449                  Coordenador             Ativo          406.45
# 159450              PROF CTPD PEDAG             Ativo          165.57
# 159451                  Coordenador             Ativo          473.39
# 159452                  Coordenador             Ativo          261.45
#
#         AbatimentoTeto  OutrosDescontos  SalarioBruto  SalarioLiquido  Diarias
# 0              3511.81         11516.46      38974.03        23945.76      0.0
# 1                 0.00         14714.46      28266.44        13551.98      0.0
# 2                 0.00          9215.62      26644.73        17429.11      0.0
# 3                 0.00         12159.20      36085.57        23926.37      0.0
# 4                 0.00          8545.36      25002.97        16457.61      0.0
# ...                ...              ...           ...             ...      ...
# 159448            0.00           642.01       4105.63         3463.62      0.0
# 159449            0.00           406.45       1884.65         1478.20      0.0
# 159450            0.00           165.57       1839.71         1674.14      0.0
# 159451            0.00           473.39       3923.40         3450.01      0.0
# 159452            0.00           261.45       2955.95         2694.50      0.0
#
# [159453 rows x 11 columns]
